# %%
library(ggplot2)
ggplot(data.frame(x = rnorm(10000), y = rnorm(10000)), aes(x = x, y = y)) +
  geom_hex() + coord_fixed() + theme_bw()
# Out:
# plot without title

# %%
install.packages("hexbin")
# Out:
# Installing package into 'C:/Users/Usuario/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'hexbin' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Usuario\AppData\Local\Temp\RtmpY7Lezy\downloaded_packages

# %%
q <- ggplot(data.frame(x = rnorm(10000), y = rnorm(10000)), aes(x = x, y = y)) +
  geom_hex() + coord_fixed() +
  scale_fill_viridis_b() + theme_bw()
q
# Out:
# plot without title

# %%
png(file = "imagenes/viridis.png")
q
dev.off()
# Out:
# png
#   2

# %%
install.packages("mapproj")
# Out:
# Installing package into 'C:/Users/Usuario/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
#
# also installing the dependency 'maps'
# package 'maps' successfully unpacked and MD5 sums checked
# package 'mapproj' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Usuario\AppData\Local\Temp\RtmpY7Lezy\downloaded_packages

# %%
library(mapproj)

data(unemp, package = "viridis")

county_df <- map_data("county", projection = "albers", parameters = c(39, 45))
names(county_df) <- c("long", "lat", "group", "order", "state_name", "county")
county_df$state <- state.abb[match(county_df$state_name, tolower(state.name))]
county_df$state_name <- NULL

state_df <- map_data("state", projection = "albers", parameters = c(39, 45))

choropleth <- merge(county_df, unemp, by = c("state", "county"))
choropleth <- choropleth[order(choropleth$order), ]

ggplot(choropleth, aes(long, lat, group = group)) +
  geom_polygon(aes(fill = rate), colour = alpha("white", 1 / 2), size = 0.2) +
  geom_polygon(data = state_df, colour = "white", fill = NA) +
  coord_fixed() +
  theme_minimal() +
  ggtitle("US unemployment rate by county") +
  theme(axis.line = element_blank(), axis.text = element_blank(),
        axis.ticks = element_blank(), axis.title = element_blank()) +
  scale_fill_viridis_c()
# Out:
# plot without title

# %%
choropleth
# Out:
#       state county    long        lat       group order id       state_fips
# 22    AL    autauga   0.1389830   -1.270973 1      1    CN010010 1
# 4     AL    autauga   0.1385475   -1.270921 1      2    CN010010 1
# 16    AL    autauga   0.1383563   -1.270743 1      3    CN010010 1
# 32    AL    autauga   0.1381651   -1.270565 1      4    CN010010 1
# 33    AL    autauga   0.1378147   -1.270504 1      5    CN010010 1
# 24    AL    autauga   0.1376557   -1.270620 1      6    CN010010 1
# 25    AL    autauga   0.1372948   -1.270460 1      7    CN010010 1
# 37    AL    autauga   0.1371781   -1.270175 1      8    CN010010 1
# 40    AL    autauga   0.1370720   -1.269987 1      9    CN010010 1
# 39    AL    autauga   0.1369022   -1.270005 1     10    CN010010 1
# 48    AL    autauga   0.1366582   -1.270131 1     11    CN010010 1
# 42    AL    autauga   0.1366156   -1.270534 1     12    CN010010 1
# 11    AL    autauga   0.1364881   -1.270945 1     13    CN010010 1
# 49    AL    autauga   0.1363182   -1.270963 1     14    CN010010 1
# 12    AL    autauga   0.1358725   -1.270812 1     15    CN010010 1
# 7     AL    autauga   0.1357456   -1.270428 1     16    CN010010 1
# 13    AL    autauga   0.1353955   -1.270366 1     17    CN010010 1
# 1     AL    autauga   0.1352363   -1.270482 1     18    CN010010 1
# 5     AL    autauga   0.1349711   -1.270411 1     19    CN010010 1
# 15    AL    autauga   0.1348117   -1.270527 1     20    CN010010 1
# 29    AL    autauga   0.1349280   -1.270813 1     21    CN010010 1
# 31    AL    autauga   0.1350442   -1.271099 1     22    CN010010 1
# 17    AL    autauga   0.1349161   -1.271511 1     23    CN010010 1
# 18    AL    autauga   0.1349474   -1.271806 1     24    CN010010 1
# 9     AL    autauga   0.1347029   -1.271931 1     25    CN010010 1
# 6     AL    autauga   0.1346074   -1.271842 1     26    CN010010 1
# 20    AL    autauga   0.1344167   -1.271663 1     27    CN010010 1
# 35    AL    autauga   0.1343959   -1.271466 1     28    CN010010 1
# 36    AL    autauga   0.1343647   -1.271171 1     29    CN010010 1
# 10    AL    autauga   0.1341533   -1.270796 1     30    CN010010 1
# ...   ...   ...       ...         ...       ...   ...   ...      ...
# 6339  AZ    la paz    -0.26838527 -1.219442 3083  90990 CN040120  4
# 6340  AZ    la paz    -0.26793144 -1.218932 3083  90991 CN040120  4
# 6314  AZ    la paz    -0.26639817 -1.218556 3083  90992 CN040120  4
# 6315  AZ    la paz    -0.26525204 -1.217994 3083  90993 CN040120  4
# 6316  AZ    la paz    -0.26451360 -1.217341 3083  90994 CN040120  4
# 6317  AZ    la paz    -0.26363702 -1.217226 3083  90995 CN040120  4
# 6318  AZ    la paz    -0.26359219 -1.216626 3083  90996 CN040120  4
# 6319  AZ    la paz    -0.26286046 -1.216785 3083  90997 CN040120  4
# 6320  AZ    la paz    -0.26209139 -1.217560 3083  90998 CN040120  4
# 6321  AZ    la paz    -0.26042418 -1.218121 3083  90999 CN040120  4
# 6322  AZ    la paz    -0.25991506 -1.218128 3083  91000 CN040120  4
# 6323  AZ    la paz    -0.25942794 -1.218638 3083  91001 CN040120  4
# 6324  AZ    la paz    -0.25761563 -1.218921 3083  91002 CN040120  4
# 6325  AZ    la paz    -0.25731085 -1.219493 3083  91003 CN040120  4
# 6326  AZ    la paz    -0.25584380 -1.219396 3083  91004 CN040120  4
# 6327  AZ    la paz    -0.25564002 -1.218830 3083  91005 CN040120  4
# 6328  AZ    la paz    -0.25484607 -1.218286 3083  91006 CN040120  4
# 6329  AZ    la paz    -0.25346196 -1.218574 3083  91007 CN040120  4
# 6330  AZ    la paz    -0.25274933 -1.218824 3083  91008 CN040120  4
# 6331  AZ    la paz    -0.25201728 -1.218570 3083  91009 CN040120  4
# 6332  AZ    la paz    -0.25314335 -1.224015 3083  91010 CN040120  4
# 82955 WI    menominee  0.08465125 -1.054310 3084  91012 CN550780 55
# 82956 WI    menominee  0.08452320 -1.052715 3084  91013 CN550780 55
# 82957 WI    menominee  0.08860257 -1.052380 3084  91014 CN550780 55
# 82958 WI    menominee  0.09057136 -1.052212 3084  91015 CN550780 55
# 82959 WI    menominee  0.09089524 -1.056801 3084  91016 CN550780 55
# 82960 WI    menominee  0.08785838 -1.057058 3084  91017 CN550780 55
# 82961 WI    menominee  0.08773412 -1.055563 3084  91018 CN550780 55
# 82962 WI    menominee  0.08470075 -1.055811 3084  91019 CN550780 55
# 82954 WI    menominee  0.08465125 -1.054310 3084  91020 CN550780 55
#       county_fips name                 year rate
# 22    1           Autauga County, AL   2009 9.7
# 4     1           Autauga County, AL   2009 9.7
# 16    1           Autauga County, AL   2009 9.7
# 32    1           Autauga County, AL   2009 9.7
# 33    1           Autauga County, AL   2009 9.7
# 24    1           Autauga County, AL   2009 9.7
# 25    1           Autauga County, AL   2009 9.7
# 37    1           Autauga County, AL   2009 9.7
# 40    1           Autauga County, AL   2009 9.7
# 39    1           Autauga County, AL   2009 9.7
# 48    1           Autauga County, AL   2009 9.7
# 42    1           Autauga County, AL   2009 9.7
# 11    1           Autauga County, AL   2009 9.7
# 49    1           Autauga County, AL   2009 9.7
# 12    1           Autauga County, AL   2009 9.7
# 7     1           Autauga County, AL   2009 9.7
# 13    1           Autauga County, AL   2009 9.7
# 1     1           Autauga County, AL   2009 9.7
# 5     1           Autauga County, AL   2009 9.7
# 15    1           Autauga County, AL   2009 9.7
# 29    1           Autauga County, AL   2009 9.7
# 31    1           Autauga County, AL   2009 9.7
# 17    1           Autauga County, AL   2009 9.7
# 18    1           Autauga County, AL   2009 9.7
# 9     1           Autauga County, AL   2009 9.7
# 6     1           Autauga County, AL   2009 9.7
# 20    1           Autauga County, AL   2009 9.7
# 35    1           Autauga County, AL   2009 9.7
# 36    1           Autauga County, AL   2009 9.7
# 10    1           Autauga County, AL   2009 9.7
# ...   ...         ...                  ...  ...
# 6339  12          La Paz County, AZ    2009  8.9
# 6340  12          La Paz County, AZ    2009  8.9
# 6314  12          La Paz County, AZ    2009  8.9
# 6315  12          La Paz County, AZ    2009  8.9
# 6316  12          La Paz County, AZ    2009  8.9
# 6317  12          La Paz County, AZ    2009  8.9
# 6318  12          La Paz County, AZ    2009  8.9
# 6319  12          La Paz County, AZ    2009  8.9
# 6320  12          La Paz County, AZ    2009  8.9
# 6321  12          La Paz County, AZ    2009  8.9
# 6322  12          La Paz County, AZ    2009  8.9
# 6323  12          La Paz County, AZ    2009  8.9
# 6324  12          La Paz County, AZ    2009  8.9
# 6325  12          La Paz County, AZ    2009  8.9
# 6326  12          La Paz County, AZ    2009  8.9
# 6327  12          La Paz County, AZ    2009  8.9
# 6328  12          La Paz County, AZ    2009  8.9
# 6329  12          La Paz County, AZ    2009  8.9
# 6330  12          La Paz County, AZ    2009  8.9
# 6331  12          La Paz County, AZ    2009  8.9
# 6332  12          La Paz County, AZ    2009  8.9
# 82955 78          Menominee County, WI 2009 12.7
# 82956 78          Menominee County, WI 2009 12.7
# 82957 78          Menominee County, WI 2009 12.7
# 82958 78          Menominee County, WI 2009 12.7
# 82959 78          Menominee County, WI 2009 12.7
# 82960 78          Menominee County, WI 2009 12.7
# 82961 78          Menominee County, WI 2009 12.7
# 82962 78          Menominee County, WI 2009 12.7
# 82954 78          Menominee County, WI 2009 12.7

# %%
# Prepare binning
spdf_fortified$bin <- cut( spdf_fortified$y_2015 , breaks=c(seq(5,10), Inf), labels=c("5-6", "6-7", "7-8", "8-9", "9-10", "10+" ), include.lowest = TRUE )
 
# Prepare a color scale coming from the viridis color palette
library(viridis)
my_palette <- rev(magma(8))[c(-1,-8)]
 
# plot
ggplot() +
  geom_polygon(data = spdf_fortified, aes(fill = bin, x = long, y = lat, group = group) , size=0, alpha=0.9) +
  geom_text(data=centers, aes(x=x, y=y, label=id), color="white", size=3, alpha=0.6) +
  theme_void() +
  scale_fill_manual( 
    values=my_palette, 
    name="Wedding per 1000 people in 2015", 
    guide = guide_legend( keyheight = unit(3, units = "mm"), keywidth=unit(12, units = "mm"), label.position = "bottom", title.position = 'top', nrow=1) 
  ) +
  ggtitle( "A map of marriage rates, state by state" ) +
  theme(
    legend.position = c(0.5, 0.9),
    text = element_text(color = "#22211d"),
    plot.background = element_rect(fill = "#f5f5f2", color = NA), 
    panel.background = element_rect(fill = "#f5f5f2", color = NA), 
    legend.background = element_rect(fill = "#f5f5f2", color = NA),
    plot.title = element_text(size= 22, hjust=0.5, color = "#4e4d47", margin = margin(b = -0.1, t = 0.4, l = 2, unit = "cm")),
  )
# Out:
# Error in cut(spdf_fortified$y_2015, breaks = c(seq(5, 10), Inf), labels = c("5-6", : objeto 'spdf_fortified' no encontrado
# Traceback:
#
# 1. cut(spdf_fortified$y_2015, breaks = c(seq(5, 10), Inf), labels = c("5-6",
#  .     "6-7", "7-8", "8-9", "9-10", "10+"), include.lowest = TRUE)

# %%
# Build 10 images -> save them at .png format
png(file="example%02d.png", width=480, height=480)
par(bg="grey")
  for (i in c(10:1, "G0!")){
    plot.new()
    text(.5, .5, i, cex = 6 )
  }
dev.off()

# Use image magick
system("convert -delay 80 *.png animated_count_down.gif")
file.remove(list.files(pattern=".png"))
# Out:
# png
#   2
# [1] 4

# %%
system("convert -delay 80 *.png animated_count_down.gif")
# Out:
# [1] 4
